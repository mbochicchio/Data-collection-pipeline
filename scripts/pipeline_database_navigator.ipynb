# %%
import duckdb
conn = duckdb.connect("../data/pipeline.duckdb")

# %%
conn.execute("SHOW TABLES").fetchall()
# Out:
# [('analyses',), ('projects',), ('versions',)]

# %%
projects_list = conn.execute("SELECT * FROM projects").fetchall()
projects_list
# Out:
# [(1,
#   'pytorch/pytorch',
#   'pytorch',
#   'pytorch',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 25, 870871)),
#  (2,
#   'Shubhamsaboo/awesome-llm-apps',
#   'Shubhamsaboo',
#   'awesome-llm-apps',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 406544)),
#  (3,
#   'fastapi/fastapi',
#   'fastapi',
#   'fastapi',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 412608)),
#  (4,
#   'nvbn/thefuck',
#   'nvbn',
#   'thefuck',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 418314)),
#  (5,
#   'openai/whisper',
#   'openai',
#   'whisper',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 424086)),
#  (6,
#   'microsoft/markitdown',
#   'microsoft',
#   'markitdown',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 431647)),
#  (7,
#   'django/django',
#   'django',
#   'django',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 437780)),
#  (8,
#   'home-assistant/core',
#   'home-assistant',
#   'core',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 444531)),
#  (9,
#   '3b1b/manim',
#   '3b1b',
#   'manim',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 450581)),
#  (10,
#   'bregman-arie/devops-exercises',
#   'bregman-arie',
#   'devops-exercises',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 456938)),
#  (11,
#   'hacksider/Deep-Live-Cam',
#   'hacksider',
#   'Deep-Live-Cam',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 463425)),
#  (12,
#   'fighting41love/funNLP',
#   'fighting41love',
#   'funNLP',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 470279)),
#  (13,
#   'browser-use/browser-use',
#   'browser-use',
#   'browser-use',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 476552)),
#  (14,
#   'tensorflow/models',
#   'tensorflow',
#   'models',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 482792)),
#  (15,
#   'd2l-ai/d2l-zh',
#   'd2l-ai',
#   'd2l-zh',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 489743)),
#  (16,
#   'swisskyrepo/PayloadsAllTheThings',
#   'swisskyrepo',
#   'PayloadsAllTheThings',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 495913)),
#  (17,
#   'anthropics/skills',
#   'anthropics',
#   'skills',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 502148)),
#  (18,
#   'infiniflow/ragflow',
#   'infiniflow',
#   'ragflow',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 508130)),
#  (19,
#   'sherlock-project/sherlock',
#   'sherlock-project',
#   'sherlock',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 514529)),
#  (20,
#   'github/spec-kit',
#   'github',
#   'spec-kit',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 520420)),
#  (21,
#   'josephmisiti/awesome-machine-learning',
#   'josephmisiti',
#   'awesome-machine-learning',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 526639)),
#  (22,
#   'python/cpython',
#   'python',
#   'cpython',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 532910)),
#  (23,
#   'pallets/flask',
#   'pallets',
#   'flask',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 539408)),
#  (24,
#   'PaddlePaddle/PaddleOCR',
#   'PaddlePaddle',
#   'PaddleOCR',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 545605)),
#  (25,
#   'vllm-project/vllm',
#   'vllm-project',
#   'vllm',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 552652)),
#  (26,
#   'binary-husky/gpt_academic',
#   'binary-husky',
#   'gpt_academic',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 559070)),
#  (27,
#   'OpenHands/OpenHands',
#   'OpenHands',
#   'OpenHands',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 565186)),
#  (28,
#   'ansible/ansible',
#   'ansible',
#   'ansible',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 571923)),
#  (29,
#   'hiyouga/LlamaFactory',
#   'hiyouga',
#   'LlamaFactory',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 578103)),
#  (30,
#   'labmlai/annotated_deep_learning_paper_implementations',
#   'labmlai',
#   'annotated_deep_learning_paper_implementations',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 584838)),
#  (31,
#   'xtekky/gpt4free',
#   'xtekky',
#   'gpt4free',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 591484)),
#  (32,
#   'scikit-learn/scikit-learn',
#   'scikit-learn',
#   'scikit-learn',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 598567)),
#  (33,
#   'localstack/localstack',
#   'localstack',
#   'localstack',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 605541)),
#  (34,
#   'FoundationAgents/MetaGPT',
#   'FoundationAgents',
#   'MetaGPT',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 611928)),
#  (35,
#   'keras-team/keras',
#   'keras-team',
#   'keras',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 618944)),
#  (36,
#   'openinterpreter/open-interpreter',
#   'openinterpreter',
#   'open-interpreter',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 625007)),
#  (37,
#   'OpenBB-finance/OpenBB',
#   'OpenBB-finance',
#   'OpenBB',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 631662)),
#  (38,
#   'unclecode/crawl4ai',
#   'unclecode',
#   'crawl4ai',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 638269)),
#  (39,
#   'commaai/openpilot',
#   'commaai',
#   'openpilot',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 644901)),
#  (40,
#   'scrapy/scrapy',
#   'scrapy',
#   'scrapy',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 651841)),
#  (41,
#   'pathwaycom/pathway',
#   'pathwaycom',
#   'pathway',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 658818)),
#  (42,
#   'CorentinJ/Real-Time-Voice-Cloning',
#   'CorentinJ',
#   'Real-Time-Voice-Cloning',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 665637)),
#  (43,
#   'meta-llama/llama',
#   'meta-llama',
#   'llama',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 672960)),
#  (44,
#   'Asabeneh/30-Days-Of-Python',
#   'Asabeneh',
#   '30-Days-Of-Python',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 679664)),
#  (45,
#   'zylon-ai/private-gpt',
#   'zylon-ai',
#   'private-gpt',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 686619)),
#  (46,
#   'ultralytics/yolov5',
#   'ultralytics',
#   'yolov5',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 693060)),
#  (47,
#   'soimort/you-get',
#   'soimort',
#   'you-get',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 699946)),
#  (48,
#   'ageitgey/face_recognition',
#   'ageitgey',
#   'face_recognition',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 706656)),
#  (49,
#   'Textualize/rich',
#   'Textualize',
#   'rich',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 712883)),
#  (50,
#   'RVC-Boss/GPT-SoVITS',
#   'RVC-Boss',
#   'GPT-SoVITS',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 719720)),
#  (51,
#   'AntonOsika/gpt-engineer',
#   'AntonOsika',
#   'gpt-engineer',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 726353)),
#  (52,
#   'Z4nzu/hackingtool',
#   'Z4nzu',
#   'hackingtool',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 733751)),
#  (53,
#   'deepfakes/faceswap',
#   'deepfakes',
#   'faceswap',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 740979)),
#  (54,
#   'opendatalab/MinerU',
#   'opendatalab',
#   'MinerU',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 749305)),
#  (55,
#   'microsoft/autogen',
#   'microsoft',
#   'autogen',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 756464)),
#  (56,
#   'FoundationAgents/OpenManus',
#   'FoundationAgents',
#   'OpenManus',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 763648)),
#  (57,
#   'docling-project/docling',
#   'docling-project',
#   'docling',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 770465)),
#  (58,
#   'psf/requests',
#   'psf',
#   'requests',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 777492)),
#  (59,
#   'karpathy/nanoGPT',
#   'karpathy',
#   'nanoGPT',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 784435)),
#  (60,
#   'ultralytics/ultralytics',
#   'ultralytics',
#   'ultralytics',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 792015)),
#  (61,
#   'unslothai/unsloth',
#   'unslothai',
#   'unsloth',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 799314)),
#  (62,
#   'Zie619/n8n-workflows',
#   'Zie619',
#   'n8n-workflows',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 805790)),
#  (63,
#   'xai-org/grok-1',
#   'xai-org',
#   'grok-1',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 812721)),
#  (64,
#   'charlax/professional-programming',
#   'charlax',
#   'professional-programming',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 819701)),
#  (65,
#   'harry0703/MoneyPrinterTurbo',
#   'harry0703',
#   'MoneyPrinterTurbo',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 826681)),
#  (66,
#   'odoo/odoo',
#   'odoo',
#   'odoo',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 833704)),
#  (67,
#   'mem0ai/mem0',
#   'mem0ai',
#   'mem0',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 840188)),
#  (68,
#   'pandas-dev/pandas',
#   'pandas-dev',
#   'pandas',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 847239)),
#  (69,
#   'lllyasviel/Fooocus',
#   'lllyasviel',
#   'Fooocus',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 854116)),
#  (70,
#   'minimaxir/big-list-of-naughty-strings',
#   'minimaxir',
#   'big-list-of-naughty-strings',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 860607)),
#  (71,
#   'sansan0/TrendRadar',
#   'sansan0',
#   'TrendRadar',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 867719)),
#  (72,
#   'run-llama/llama_index',
#   'run-llama',
#   'llama_index',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 874507)),
#  (73,
#   'freqtrade/freqtrade',
#   'freqtrade',
#   'freqtrade',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 881535)),
#  (74,
#   'oobabooga/text-generation-webui',
#   'oobabooga',
#   'text-generation-webui',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 888909)),
#  (75,
#   'virattt/ai-hedge-fund',
#   'virattt',
#   'ai-hedge-fund',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 895654)),
#  (76,
#   'coqui-ai/TTS',
#   'coqui-ai',
#   'TTS',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 903525)),
#  (77,
#   'crewAIInc/crewAI',
#   'crewAIInc',
#   'crewAI',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 910808)),
#  (78,
#   'apache/airflow',
#   'apache',
#   'airflow',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 918182)),
#  (79,
#   'NanmiCoder/MediaCrawler',
#   'NanmiCoder',
#   'MediaCrawler',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 926095)),
#  (80,
#   'karpathy/nanochat',
#   'karpathy',
#   'nanochat',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 933133)),
#  (81,
#   'streamlit/streamlit',
#   'streamlit',
#   'streamlit',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 939821)),
#  (82,
#   'SimplifyJobs/Summer2026-Internships',
#   'SimplifyJobs',
#   'Summer2026-Internships',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 946742)),
#  (83,
#   'getsentry/sentry',
#   'getsentry',
#   'sentry',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 953851)),
#  (84,
#   'faif/python-patterns',
#   'faif',
#   'python-patterns',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 961757)),
#  (85,
#   '9001/copyparty',
#   '9001',
#   'copyparty',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 968593)),
#  (86,
#   'mitmproxy/mitmproxy',
#   'mitmproxy',
#   'mitmproxy',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 975410)),
#  (87,
#   'hiroi-sora/Umi-OCR',
#   'hiroi-sora',
#   'Umi-OCR',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 982694)),
#  (88,
#   'apachecn/ailearning',
#   'apachecn',
#   'ailearning',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 989261)),
#  (89,
#   'mingrammer/diagrams',
#   'mingrammer',
#   'diagrams',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 26, 996040)),
#  (90,
#   'gradio-app/gradio',
#   'gradio-app',
#   'gradio',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 2935)),
#  (91,
#   'exo-explore/exo',
#   'exo-explore',
#   'exo',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 10995)),
#  (92,
#   'deepspeedai/DeepSpeed',
#   'deepspeedai',
#   'DeepSpeed',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 18561)),
#  (93,
#   'ray-project/ray',
#   'ray-project',
#   'ray',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 25558)),
#  (94,
#   'zhayujie/chatgpt-on-wechat',
#   'zhayujie',
#   'chatgpt-on-wechat',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 32994)),
#  (95,
#   'psf/black',
#   'psf',
#   'black',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 40731)),
#  (96,
#   'hpcaitech/ColossalAI',
#   'hpcaitech',
#   'ColossalAI',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 48215)),
#  (97,
#   'zai-org/ChatGLM-6B',
#   'zai-org',
#   'ChatGLM-6B',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 54813)),
#  (98,
#   'ccxt/ccxt',
#   'ccxt',
#   'ccxt',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 62178)),
#  (99,
#   'chubin/cheat.sh',
#   'chubin',
#   'cheat.sh',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 69961)),
#  (100,
#   'Aider-AI/aider',
#   'Aider-AI',
#   'aider',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 77247)),
#  (101,
#   'jingyaogong/minimind',
#   'jingyaogong',
#   'minimind',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 84644)),
#  (102,
#   'google-research/bert',
#   'google-research',
#   'bert',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 91416)),
#  (103,
#   'floodsung/Deep-Learning-Papers-Reading-Roadmap',
#   'floodsung',
#   'Deep-Learning-Papers-Reading-Roadmap',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 98258)),
#  (104,
#   'lm-sys/FastChat',
#   'lm-sys',
#   'FastChat',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 105374)),
#  (105,
#   'QuivrHQ/quivr',
#   'QuivrHQ',
#   'quivr',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 112937)),
#  (106,
#   '2noise/ChatTTS',
#   '2noise',
#   'ChatTTS',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 120553)),
#  (107,
#   'mindsdb/mindsdb',
#   'mindsdb',
#   'mindsdb',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 127960)),
#  (108,
#   'gto76/python-cheatsheet',
#   'gto76',
#   'python-cheatsheet',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 134991)),
#  (109,
#   'agno-agi/agno',
#   'agno-agi',
#   'agno',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 142487)),
#  (110,
#   'microsoft/qlib',
#   'microsoft',
#   'qlib',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 149727)),
#  (111,
#   'httpie/cli',
#   'httpie',
#   'cli',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 156747)),
#  (112,
#   'ComposioHQ/awesome-claude-skills',
#   'ComposioHQ',
#   'awesome-claude-skills',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 168793)),
#  (113,
#   'LAION-AI/Open-Assistant',
#   'LAION-AI',
#   'Open-Assistant',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 179088)),
#  (114,
#   'TencentARC/GFPGAN',
#   'TencentARC',
#   'GFPGAN',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 188350)),
#  (115,
#   'chatchat-space/Langchain-Chatchat',
#   'chatchat-space',
#   'Langchain-Chatchat',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 199734)),
#  (116,
#   '0voice/interview_internal_reference',
#   '0voice',
#   'interview_internal_reference',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 209906)),
#  (117,
#   'openai/gym',
#   'openai',
#   'gym',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 219480)),
#  (118,
#   'paperless-ngx/paperless-ngx',
#   'paperless-ngx',
#   'paperless-ngx',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 229463)),
#  (119,
#   'ManimCommunity/manim',
#   'ManimCommunity',
#   'manim',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 238929)),
#  (120,
#   'satwikkansal/wtfpython',
#   'satwikkansal',
#   'wtfpython',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 248159)),
#  (121,
#   'vnpy/vnpy',
#   'vnpy',
#   'vnpy',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 259769)),
#  (122,
#   'babysor/MockingBird',
#   'babysor',
#   'MockingBird',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 268604)),
#  (123,
#   'BerriAI/litellm',
#   'BerriAI',
#   'litellm',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 278501)),
#  (124,
#   'sqlmapproject/sqlmap',
#   'sqlmapproject',
#   'sqlmap',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 287577)),
#  (125,
#   'roboflow/supervision',
#   'roboflow',
#   'supervision',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 296993)),
#  (126,
#   'huggingface/pytorch-image-models',
#   'huggingface',
#   'pytorch-image-models',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 307965)),
#  (127,
#   'chatanywhere/GPT_API_free',
#   'chatanywhere',
#   'GPT_API_free',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 316606)),
#  (128,
#   'hankcs/HanLP',
#   'hankcs',
#   'HanLP',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 326881)),
#  (129,
#   'myshell-ai/OpenVoice',
#   'myshell-ai',
#   'OpenVoice',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 335703)),
#  (130,
#   'XingangPan/DragGAN',
#   'XingangPan',
#   'DragGAN',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 344320)),
#  (131,
#   '666ghj/BettaFish',
#   '666ghj',
#   'BettaFish',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 354829)),
#  (132,
#   'jax-ml/jax',
#   'jax-ml',
#   'jax',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 363754)),
#  (133,
#   'geekcomputers/Python',
#   'geekcomputers',
#   'Python',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 373104)),
#  (134,
#   'fxsjy/jieba',
#   'fxsjy',
#   'jieba',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 381898)),
#  (135,
#   'RVC-Project/Retrieval-based-Voice-Conversion-WebUI',
#   'RVC-Project',
#   'Retrieval-based-Voice-Conversion-WebUI',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 391259)),
#  (136,
#   'mouredev/Hello-Python',
#   'mouredev',
#   'Hello-Python',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 400576)),
#  (137,
#   'Textualize/textual',
#   'Textualize',
#   'textual',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 411616)),
#  (138,
#   'nextlevelbuilder/ui-ux-pro-max-skill',
#   'nextlevelbuilder',
#   'ui-ux-pro-max-skill',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 421197)),
#  (139,
#   'xinntao/Real-ESRGAN',
#   'xinntao',
#   'Real-ESRGAN',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 432571)),
#  (140,
#   'python-poetry/poetry',
#   'python-poetry',
#   'poetry',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 440862)),
#  (141,
#   'chenfei-wu/TaskMatrix',
#   'chenfei-wu',
#   'TaskMatrix',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 450302)),
#  (142,
#   'testerSunshine/12306',
#   'testerSunshine',
#   '12306',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 460316)),
#  (143,
#   'facebookresearch/detectron2',
#   'facebookresearch',
#   'detectron2',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 469098)),
#  (144,
#   'Pythagora-io/gpt-pilot',
#   'Pythagora-io',
#   'gpt-pilot',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 478755)),
#  (145,
#   'google/langextract',
#   'google',
#   'langextract',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 487059)),
#  (146,
#   'lllyasviel/ControlNet',
#   'lllyasviel',
#   'ControlNet',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 497060)),
#  (147,
#   'shadowsocks/shadowsocks',
#   'shadowsocks',
#   'shadowsocks',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 505911)),
#  (148,
#   'XX-net/XX-Net',
#   'XX-net',
#   'XX-Net',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 516986)),
#  (149,
#   'explosion/spaCy',
#   'explosion',
#   'spaCy',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 526454)),
#  (150,
#   'certbot/certbot',
#   'certbot',
#   'certbot',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 536270)),
#  (151,
#   'huggingface/diffusers',
#   'huggingface',
#   'diffusers',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 546938)),
#  (152,
#   'ocrmypdf/OCRmyPDF',
#   'ocrmypdf',
#   'OCRmyPDF',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 565922)),
#  (153,
#   'khoj-ai/khoj',
#   'khoj-ai',
#   'khoj',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 586873)),
#  (154,
#   'open-mmlab/mmdetection',
#   'open-mmlab',
#   'mmdetection',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 601775)),
#  (155,
#   'stanfordnlp/dspy',
#   'stanfordnlp',
#   'dspy',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 612913)),
#  (156,
#   '0xAX/linux-insides',
#   '0xAX',
#   'linux-insides',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 624344)),
#  (157,
#   'yunjey/pytorch-tutorial',
#   'yunjey',
#   'pytorch-tutorial',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 635205)),
#  (158,
#   'facebookresearch/fairseq',
#   'facebookresearch',
#   'fairseq',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 647410)),
#  (159,
#   'frappe/erpnext',
#   'frappe',
#   'erpnext',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 659689)),
#  (160,
#   'datalab-to/marker',
#   'datalab-to',
#   'marker',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 681027)),
#  (161,
#   'PDFMathTranslate/PDFMathTranslate',
#   'PDFMathTranslate',
#   'PDFMathTranslate',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 694870)),
#  (162,
#   'nicolargo/glances',
#   'nicolargo',
#   'glances',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 705156)),
#  (163,
#   'PostHog/posthog',
#   'PostHog',
#   'posthog',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 718075)),
#  (164,
#   'numpy/numpy',
#   'numpy',
#   'numpy',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 728052)),
#  (165,
#   'kovidgoyal/kitty',
#   'kovidgoyal',
#   'kitty',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 738995)),
#  (166,
#   'tinygrad/tinygrad',
#   'tinygrad',
#   'tinygrad',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 751020)),
#  (167,
#   'OWASP/CheatSheetSeries',
#   'OWASP',
#   'CheatSheetSeries',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 761973)),
#  (168,
#   'donnemartin/interactive-coding-challenges',
#   'donnemartin',
#   'interactive-coding-challenges',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 772740)),
#  (169,
#   'OpenBMB/ChatDev',
#   'OpenBMB',
#   'ChatDev',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 783368)),
#  (170,
#   'microsoft/graphrag',
#   'microsoft',
#   'graphrag',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 793370)),
#  (171,
#   'tqdm/tqdm',
#   'tqdm',
#   'tqdm',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 803678)),
#  (172,
#   'eriklindernoren/ML-From-Scratch',
#   'eriklindernoren',
#   'ML-From-Scratch',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 812802)),
#  (173,
#   'Lightning-AI/pytorch-lightning',
#   'Lightning-AI',
#   'pytorch-lightning',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 822867)),
#  (174,
#   'TauricResearch/TradingAgents',
#   'TauricResearch',
#   'TradingAgents',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 831757)),
#  (175,
#   'iperov/DeepFaceLive',
#   'iperov',
#   'DeepFaceLive',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 840168)),
#  (176,
#   's0md3v/roop',
#   's0md3v',
#   'roop',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 847837)),
#  (177,
#   'trailofbits/algo',
#   'trailofbits',
#   'algo',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 855796)),
#  (178,
#   'dgtlmoon/changedetection.io',
#   'dgtlmoon',
#   'changedetection.io',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 863498)),
#  (179,
#   'tatsu-lab/stanford_alpaca',
#   'tatsu-lab',
#   'stanford_alpaca',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 872749)),
#  (180,
#   'openai/openai-python',
#   'openai',
#   'openai-python',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 880632)),
#  (181,
#   'jumpserver/jumpserver',
#   'jumpserver',
#   'jumpserver',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 888660)),
#  (182,
#   'encode/django-rest-framework',
#   'encode',
#   'django-rest-framework',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 896816)),
#  (183,
#   'StevenBlack/hosts',
#   'StevenBlack',
#   'hosts',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 904325)),
#  (184,
#   'feder-cr/Jobs_Applier_AI_Agent_AIHawk',
#   'feder-cr',
#   'Jobs_Applier_AI_Agent_AIHawk',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 912615)),
#  (185,
#   'wshobson/agents',
#   'wshobson',
#   'agents',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 920404)),
#  (186,
#   'meta-llama/llama3',
#   'meta-llama',
#   'llama3',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 927773)),
#  (187,
#   'JaidedAI/EasyOCR',
#   'JaidedAI',
#   'EasyOCR',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 935719)),
#  (188,
#   'donnemartin/data-science-ipython-notebooks',
#   'donnemartin',
#   'data-science-ipython-notebooks',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 943138)),
#  (189,
#   'chubin/wttr.in',
#   'chubin',
#   'wttr.in',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 951102)),
#  (190,
#   'python-telegram-bot/python-telegram-bot',
#   'python-telegram-bot',
#   'python-telegram-bot',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 958983)),
#  (191,
#   'AtsushiSakai/PythonRobotics',
#   'AtsushiSakai',
#   'PythonRobotics',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 966573)),
#  (192,
#   'HKUDS/LightRAG',
#   'HKUDS',
#   'LightRAG',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 974310)),
#  (193,
#   'Ebazhanov/linkedin-skill-assessments-quizzes',
#   'Ebazhanov',
#   'linkedin-skill-assessments-quizzes',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 982436)),
#  (194,
#   'hpcaitech/Open-Sora',
#   'hpcaitech',
#   'Open-Sora',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 990327)),
#  (195,
#   'microsoft/BitNet',
#   'microsoft',
#   'BitNet',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 27, 998169)),
#  (196,
#   'getredash/redash',
#   'getredash',
#   'redash',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 5692)),
#  (197,
#   'd2l-ai/d2l-en',
#   'd2l-ai',
#   'd2l-en',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 13798)),
#  (198,
#   'Genesis-Embodied-AI/Genesis',
#   'Genesis-Embodied-AI',
#   'Genesis',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 21333)),
#  (199,
#   'reflex-dev/reflex',
#   'reflex-dev',
#   'reflex',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 29919)),
#  (200,
#   'celery/celery',
#   'celery',
#   'celery',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 37933)),
#  (201,
#   'google/python-fire',
#   'google',
#   'python-fire',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 45473)),
#  (202,
#   'deezer/spleeter',
#   'deezer',
#   'spleeter',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 53407)),
#  (203,
#   'svc-develop-team/so-vits-svc',
#   'svc-develop-team',
#   'so-vits-svc',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 62773)),
#  (204,
#   'acheong08/ChatGPT',
#   'acheong08',
#   'ChatGPT',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 71043)),
#  (205,
#   'deepinsight/insightface',
#   'deepinsight',
#   'insightface',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 78659)),
#  (206,
#   'stanford-oval/storm',
#   'stanford-oval',
#   'storm',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 86829)),
#  (207,
#   '521xueweihan/GitHub520',
#   '521xueweihan',
#   'GitHub520',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 95193)),
#  (208,
#   'microsoft/cascadia-code',
#   'microsoft',
#   'cascadia-code',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 103673)),
#  (209,
#   'locustio/locust',
#   'locustio',
#   'locust',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 111269)),
#  (210,
#   'KurtBestor/Hitomi-Downloader',
#   'KurtBestor',
#   'Hitomi-Downloader',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 119397)),
#  (211,
#   'MetaCubeX/mihomo',
#   'MetaCubeX',
#   'mihomo',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 127545)),
#  (212,
#   'pydantic/pydantic',
#   'pydantic',
#   'pydantic',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 135334)),
#  (213,
#   'ArchiveBox/ArchiveBox',
#   'ArchiveBox',
#   'ArchiveBox',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 143090)),
#  (214,
#   'Stability-AI/generative-models',
#   'Stability-AI',
#   'generative-models',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 151192)),
#  (215,
#   'facefusion/facefusion',
#   'facefusion',
#   'facefusion',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 159026)),
#  (216,
#   'littlecodersh/ItChat',
#   'littlecodersh',
#   'ItChat',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 167349)),
#  (217,
#   'QwenLM/Qwen3',
#   'QwenLM',
#   'Qwen3',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 175452)),
#  (218,
#   'facebookresearch/Detectron',
#   'facebookresearch',
#   'Detectron',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 184707)),
#  (219,
#   'ycm-core/YouCompleteMe',
#   'ycm-core',
#   'YouCompleteMe',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 193374)),
#  (220,
#   'squidfunk/mkdocs-material',
#   'squidfunk',
#   'mkdocs-material',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 201478)),
#  (221,
#   'WZMIAOMIAO/deep-learning-for-image-processing',
#   'WZMIAOMIAO',
#   'deep-learning-for-image-processing',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 209890)),
#  (222,
#   'huggingface/open-r1',
#   'huggingface',
#   'open-r1',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 218235)),
#  (223,
#   'ungoogled-software/ungoogled-chromium',
#   'ungoogled-software',
#   'ungoogled-chromium',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 226105)),
#  (224,
#   'Vision-CAIR/MiniGPT-4',
#   'Vision-CAIR',
#   'MiniGPT-4',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 233924)),
#  (225,
#   'huggingface/smolagents',
#   'huggingface',
#   'smolagents',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 242017)),
#  (226,
#   'matterport/Mask_RCNN',
#   'matterport',
#   'Mask_RCNN',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 250443)),
#  (227,
#   'assafelovic/gpt-researcher',
#   'assafelovic',
#   'gpt-researcher',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 258836)),
#  (228,
#   'keon/algorithms',
#   'keon',
#   'algorithms',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 267139)),
#  (229,
#   'searxng/searxng',
#   'searxng',
#   'searxng',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 275501)),
#  (230,
#   'black-forest-labs/flux',
#   'black-forest-labs',
#   'flux',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 284070)),
#  (231,
#   'Cinnamon/kotaemon',
#   'Cinnamon',
#   'kotaemon',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 292013)),
#  (232,
#   'Fosowl/agenticSeek',
#   'Fosowl',
#   'agenticSeek',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 300125)),
#  (233,
#   'pypa/pipenv',
#   'pypa',
#   'pipenv',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 308358)),
#  (234,
#   'langchain-ai/langgraph',
#   'langchain-ai',
#   'langgraph',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 316722)),
#  (235,
#   'fishaudio/fish-speech',
#   'fishaudio',
#   'fish-speech',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 324530)),
#  (236,
#   'hesreallyhim/awesome-claude-code',
#   'hesreallyhim',
#   'awesome-claude-code',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 332811)),
#  (237,
#   'junyanz/pytorch-CycleGAN-and-pix2pix',
#   'junyanz',
#   'pytorch-CycleGAN-and-pix2pix',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 341141)),
#  (238,
#   'HKUDS/nanobot',
#   'HKUDS',
#   'nanobot',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 349403)),
#  (239,
#   'HumanSignal/labelImg',
#   'HumanSignal',
#   'labelImg',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 358101)),
#  (240,
#   'zulip/zulip',
#   'zulip',
#   'zulip',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 366812)),
#  (241,
#   'cookiecutter/cookiecutter',
#   'cookiecutter',
#   'cookiecutter',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 375963)),
#  (242,
#   'openai/gpt-2',
#   'openai',
#   'gpt-2',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 384613)),
#  (243,
#   'microsoft/JARVIS',
#   'microsoft',
#   'JARVIS',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 392760)),
#  (244,
#   'plotly/dash',
#   'plotly',
#   'dash',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 401572)),
#  (245,
#   'haotian-liu/LLaVA',
#   'haotian-liu',
#   'LLaVA',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 409272)),
#  (246,
#   'mlflow/mlflow',
#   'mlflow',
#   'mlflow',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 417520)),
#  (247,
#   'kovidgoyal/calibre',
#   'kovidgoyal',
#   'calibre',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 426063)),
#  (248,
#   'subframe7536/maple-font',
#   'subframe7536',
#   'maple-font',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 434133)),
#  (249,
#   'spotDL/spotify-downloader',
#   'spotDL',
#   'spotify-downloader',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 441839)),
#  (250,
#   'OpenBMB/MiniCPM-o',
#   'OpenBMB',
#   'MiniCPM-o',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 450371)),
#  (251,
#   'pytorch/examples',
#   'pytorch',
#   'examples',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 459223)),
#  (252,
#   'sgl-project/sglang',
#   'sgl-project',
#   'sglang',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 467502)),
#  (253,
#   'Anjok07/ultimatevocalremovergui',
#   'Anjok07',
#   'ultimatevocalremovergui',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 475485)),
#  (254,
#   'zai-org/Open-AutoGLM',
#   'zai-org',
#   'Open-AutoGLM',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 483792)),
#  (255,
#   'karpathy/minGPT',
#   'karpathy',
#   'minGPT',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 492332)),
#  (256,
#   'Delgan/loguru',
#   'Delgan',
#   'loguru',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 500296)),
#  (257,
#   'pyg-team/pytorch_geometric',
#   'pyg-team',
#   'pytorch_geometric',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 508450)),
#  (258,
#   'microsoft/VibeVoice',
#   'microsoft',
#   'VibeVoice',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 516908)),
#  (259,
#   'sinaptik-ai/pandas-ai',
#   'sinaptik-ai',
#   'pandas-ai',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 525446)),
#  (260,
#   'wangzheng0822/algo',
#   'wangzheng0822',
#   'algo',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 533736)),
#  (261,
#   'jhao104/proxy_pool',
#   'jhao104',
#   'proxy_pool',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 542252)),
#  (262,
#   'PrefectHQ/fastmcp',
#   'PrefectHQ',
#   'fastmcp',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 550996)),
#  (263,
#   'getzep/graphiti',
#   'getzep',
#   'graphiti',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 559837)),
#  (264,
#   'sebastianruder/NLP-progress',
#   'sebastianruder',
#   'NLP-progress',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 567785)),
#  (265,
#   'netbox-community/netbox',
#   'netbox-community',
#   'netbox',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 576179)),
#  (266,
#   'openai/gpt-oss',
#   'openai',
#   'gpt-oss',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 584164)),
#  (267,
#   'magenta/magenta',
#   'magenta',
#   'magenta',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 592125)),
#  (268,
#   'nginx-proxy/nginx-proxy',
#   'nginx-proxy',
#   'nginx-proxy',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 600487)),
#  (269,
#   'w-okada/voice-changer',
#   'w-okada',
#   'voice-changer',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 609592)),
#  (270,
#   'FunAudioLLM/CosyVoice',
#   'FunAudioLLM',
#   'CosyVoice',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 618021)),
#  (271,
#   'Jack-Cherish/python-spider',
#   'Jack-Cherish',
#   'python-spider',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 626023)),
#  (272,
#   'stitionai/devika',
#   'stitionai',
#   'devika',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 634629)),
#  (273,
#   'quantopian/zipline',
#   'quantopian',
#   'zipline',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 643449)),
#  (274,
#   'verl-project/verl',
#   'verl-project',
#   'verl',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 651785)),
#  (275,
#   'datalab-to/surya',
#   'datalab-to',
#   'surya',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 659956)),
#  (276,
#   'marimo-team/marimo',
#   'marimo-team',
#   'marimo',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 668534)),
#  (277,
#   'rsms/inter',
#   'rsms',
#   'inter',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 676911)),
#  (278,
#   'kaixindelele/ChatPaper',
#   'kaixindelele',
#   'ChatPaper',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 684970)),
#  (279,
#   'joke2k/faker',
#   'joke2k',
#   'faker',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 694437)),
#  (280,
#   'nari-labs/dia',
#   'nari-labs',
#   'dia',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 703229)),
#  (281,
#   'openai/openai-agents-python',
#   'openai',
#   'openai-agents-python',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 711372)),
#  (282,
#   'camel-ai/owl',
#   'camel-ai',
#   'owl',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 719813)),
#  (283,
#   'Avaiga/taipy',
#   'Avaiga',
#   'taipy',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 727738)),
#  (284,
#   'soxoj/maigret',
#   'soxoj',
#   'maigret',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 737805)),
#  (285,
#   'iperov/DeepFaceLab',
#   'iperov',
#   'DeepFaceLab',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 747110)),
#  (286,
#   'ymcui/Chinese-LLaMA-Alpaca',
#   'ymcui',
#   'Chinese-LLaMA-Alpaca',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 755808)),
#  (287,
#   'index-tts/index-tts',
#   'index-tts',
#   'index-tts',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 764149)),
#  (288,
#   'fastapi/typer',
#   'fastapi',
#   'typer',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 772289)),
#  (289,
#   'kivy/kivy',
#   'kivy',
#   'kivy',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 780770)),
#  (290,
#   'RunaCapital/awesome-oss-alternatives',
#   'RunaCapital',
#   'awesome-oss-alternatives',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 789246)),
#  (291,
#   'pyscript/pyscript',
#   'pyscript',
#   'pyscript',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 798484)),
#  (292,
#   'spotify/luigi',
#   'spotify',
#   'luigi',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 807230)),
#  (293,
#   'sanic-org/sanic',
#   'sanic-org',
#   'sanic',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 815980)),
#  (294,
#   'SWE-agent/SWE-agent',
#   'SWE-agent',
#   'SWE-agent',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 824355)),
#  (295,
#   'miloyip/game-programmer',
#   'miloyip',
#   'game-programmer',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 832124)),
#  (296,
#   'jantic/DeOldify',
#   'jantic',
#   'DeOldify',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 840590)),
#  (297,
#   'mxrch/GHunt',
#   'mxrch',
#   'GHunt',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 849668)),
#  (298,
#   'lss233/kirara-ai',
#   'lss233',
#   'kirara-ai',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 857670)),
#  (299,
#   'huggingface/sentence-transformers',
#   'huggingface',
#   'sentence-transformers',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 865929)),
#  (300,
#   'plotly/plotly.py',
#   'plotly',
#   'plotly.py',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 874724)),
#  (301,
#   'Alibaba-NLP/DeepResearch',
#   'Alibaba-NLP',
#   'DeepResearch',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 883143)),
#  (302,
#   'DrewThomasson/ebook2audiobook',
#   'DrewThomasson',
#   'ebook2audiobook',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 891613)),
#  (303,
#   'eosphoros-ai/DB-GPT',
#   'eosphoros-ai',
#   'DB-GPT',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 900136)),
#  (304,
#   'chidiwilliams/buzz',
#   'chidiwilliams',
#   'buzz',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 908721)),
#  (305,
#   'google/adk-python',
#   'google',
#   'adk-python',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 917522)),
#  (306,
#   'Python-World/python-mini-projects',
#   'Python-World',
#   'python-mini-projects',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 925925)),
#  (307,
#   'openai/evals',
#   'openai',
#   'evals',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 934380)),
#  (308,
#   'Mikubill/sd-webui-controlnet',
#   'Mikubill',
#   'sd-webui-controlnet',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 943024)),
#  (309,
#   'AstrBotDevs/AstrBot',
#   'AstrBotDevs',
#   'AstrBot',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 951530)),
#  (310,
#   'KlingAIResearch/LivePortrait',
#   'KlingAIResearch',
#   'LivePortrait',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 959884)),
#  (311,
#   'comet-ml/opik',
#   'comet-ml',
#   'opik',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 968421)),
#  (312,
#   'sczhou/CodeFormer',
#   'sczhou',
#   'CodeFormer',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 977139)),
#  (313,
#   'apple/ml-stable-diffusion',
#   'apple',
#   'ml-stable-diffusion',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 985368)),
#  (314,
#   'hsliuping/TradingAgents-CN',
#   'hsliuping',
#   'TradingAgents-CN',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 28, 994182)),
#  (315,
#   'InstaPy/InstaPy',
#   'InstaPy',
#   'InstaPy',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 3426)),
#  (316,
#   'emcie-co/parlant',
#   'emcie-co',
#   'parlant',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 12396)),
#  (317,
#   'trekhleb/learn-python',
#   'trekhleb',
#   'learn-python',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 21268)),
#  (318,
#   'arc53/DocsGPT',
#   'arc53',
#   'DocsGPT',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 30087)),
#  (319,
#   'deepseek-ai/Janus',
#   'deepseek-ai',
#   'Janus',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 38902)),
#  (320,
#   'fastapi/sqlmodel',
#   'fastapi',
#   'sqlmodel',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 47591)),
#  (321,
#   'onyx-dot-app/onyx',
#   'onyx-dot-app',
#   'onyx',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 56502)),
#  (322,
#   'pytorch/vision',
#   'pytorch',
#   'vision',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 65439)),
#  (323,
#   'mnielsen/neural-networks-and-deep-learning',
#   'mnielsen',
#   'neural-networks-and-deep-learning',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 73569)),
#  (324,
#   'hummingbot/hummingbot',
#   'hummingbot',
#   'hummingbot',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 82642)),
#  (325,
#   'huggingface/trl',
#   'huggingface',
#   'trl',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 91450)),
#  (326,
#   'eriklindernoren/PyTorch-GAN',
#   'eriklindernoren',
#   'PyTorch-GAN',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 100499)),
#  (327,
#   'VectifyAI/PageIndex',
#   'VectifyAI',
#   'PageIndex',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 108704)),
#  (328,
#   'openai/tiktoken',
#   'openai',
#   'tiktoken',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 117530)),
#  (329,
#   'astral-sh/ty',
#   'astral-sh',
#   'ty',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 126316)),
#  (330,
#   'ahujasid/blender-mcp',
#   'ahujasid',
#   'blender-mcp',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 135032)),
#  (331,
#   'pallets/click',
#   'pallets',
#   'click',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 143083)),
#  (332,
#   'state-spaces/mamba',
#   'state-spaces',
#   'mamba',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 151960)),
#  (333,
#   'TransformerOptimus/SuperAGI',
#   'TransformerOptimus',
#   'SuperAGI',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 162512)),
#  (334,
#   'stas00/ml-engineering',
#   'stas00',
#   'ml-engineering',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 172309)),
#  (335,
#   'binux/pyspider',
#   'binux',
#   'pyspider',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 181290)),
#  (336,
#   'fail2ban/fail2ban',
#   'fail2ban',
#   'fail2ban',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 190755)),
#  (337,
#   'tensorflow/tensor2tensor',
#   'tensorflow',
#   'tensor2tensor',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 199089)),
#  (338,
#   'mikf/gallery-dl',
#   'mikf',
#   'gallery-dl',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 207968)),
#  (339,
#   'reddit-archive/reddit',
#   'reddit-archive',
#   'reddit',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 217013)),
#  (340,
#   'allenai/olmocr',
#   'allenai',
#   'olmocr',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 225527)),
#  (341,
#   'ranger/ranger',
#   'ranger',
#   'ranger',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 233930)),
#  (342,
#   'wting/autojump',
#   'wting',
#   'autojump',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 242486)),
#  (343,
#   'NVIDIA-NeMo/NeMo',
#   'NVIDIA-NeMo',
#   'NeMo',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 251289)),
#  (344,
#   'aws/aws-cli',
#   'aws',
#   'aws-cli',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 259933)),
#  (345,
#   'ActivityWatch/activitywatch',
#   'ActivityWatch',
#   'activitywatch',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 268285)),
#  (346,
#   'smicallef/spiderfoot',
#   'smicallef',
#   'spiderfoot',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 29, 278337)),
#  (347,
#   'dortania/OpenCore-Legacy-Patcher',
#   'dortania',
# ...
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 207715)),
#  (890,
#   'apple/ml-fastvit',
#   'apple',
#   'ml-fastvit',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 220425)),
#  (891,
#   'elyra-ai/elyra',
#   'elyra-ai',
#   'elyra',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 234251)),
#  (892,
#   'salesforce/awd-lstm-lm',
#   'salesforce',
#   'awd-lstm-lm',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 247518)),
#  (893,
#   'srsudar/eg',
#   'srsudar',
#   'eg',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 261271)),
#  (894,
#   'deepcharles/ruptures',
#   'deepcharles',
#   'ruptures',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 275876)),
#  (895,
#   'django/djangoproject.com',
#   'django',
#   'djangoproject.com',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 289666)),
#  (896,
#   'AdrMXR/KitHack',
#   'AdrMXR',
#   'KitHack',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 302929)),
#  (897,
#   'me-shaon/bangla-programming-resources',
#   'me-shaon',
#   'bangla-programming-resources',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 315942)),
#  (898,
#   'cambrian-mllm/cambrian',
#   'cambrian-mllm',
#   'cambrian',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 329144)),
#  (899,
#   'x0rz/EQGRP_Lost_in_Translation',
#   'x0rz',
#   'EQGRP_Lost_in_Translation',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 342227)),
#  (900,
#   'pollen-robotics/AmazingHand',
#   'pollen-robotics',
#   'AmazingHand',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 355101)),
#  (901,
#   'albertpumarola/GANimation',
#   'albertpumarola',
#   'GANimation',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 368509)),
#  (902,
#   'y9nhjy/Proxifier-Keygen',
#   'y9nhjy',
#   'Proxifier-Keygen',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 381396)),
#  (903,
#   'harry0703/AudioNotes',
#   'harry0703',
#   'AudioNotes',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 394391)),
#  (904,
#   'mvantellingen/python-zeep',
#   'mvantellingen',
#   'python-zeep',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 407957)),
#  (905,
#   'PacktPublishing/Advanced-Deep-Learning-with-Keras',
#   'PacktPublishing',
#   'Advanced-Deep-Learning-with-Keras',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 420873)),
#  (906,
#   'ZiyaoGeng/RecLearn',
#   'ZiyaoGeng',
#   'RecLearn',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 433371)),
#  (907,
#   'ryzendew/Linux-Affinity-Installer',
#   'ryzendew',
#   'Linux-Affinity-Installer',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 445406)),
#  (908,
#   '0xemmkty/QuantMuse',
#   '0xemmkty',
#   'QuantMuse',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 457724)),
#  (909,
#   'r9y9/deepvoice3_pytorch',
#   'r9y9',
#   'deepvoice3_pytorch',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 469463)),
#  (910,
#   'H1R0GH057/Anonymous',
#   'H1R0GH057',
#   'Anonymous',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 481710)),
#  (911,
#   'Tencent/ObjectDetection-OneStageDet',
#   'Tencent',
#   'ObjectDetection-OneStageDet',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 493945)),
#  (912,
#   'clementchadebec/benchmark_VAE',
#   'clementchadebec',
#   'benchmark_VAE',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 505950)),
#  (913,
#   'pythonarcade/arcade',
#   'pythonarcade',
#   'arcade',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 517014)),
#  (914,
#   'SummitKwan/transparent_latent_gan',
#   'SummitKwan',
#   'transparent_latent_gan',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 528647)),
#  (915,
#   'haitongli/knowledge-distillation-pytorch',
#   'haitongli',
#   'knowledge-distillation-pytorch',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 541136)),
#  (916,
#   'LlmKira/Openaibot',
#   'LlmKira',
#   'Openaibot',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 552460)),
#  (917,
#   'circlestarzero/EX-chatGPT',
#   'circlestarzero',
#   'EX-chatGPT',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 564883)),
#  (918,
#   'nat-n/poethepoet',
#   'nat-n',
#   'poethepoet',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 577403)),
#  (919,
#   'BlankerL/DXY-COVID-19-Crawler',
#   'BlankerL',
#   'DXY-COVID-19-Crawler',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 589591)),
#  (920,
#   'wkeeling/selenium-wire',
#   'wkeeling',
#   'selenium-wire',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 601525)),
#  (921,
#   'mozilla-services/syncserver',
#   'mozilla-services',
#   'syncserver',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 613760)),
#  (922,
#   'Nekmo/dirhunt',
#   'Nekmo',
#   'dirhunt',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 626009)),
#  (923,
#   'uncertainty-toolbox/uncertainty-toolbox',
#   'uncertainty-toolbox',
#   'uncertainty-toolbox',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 637676)),
#  (924,
#   'fkxxyz/rime-cloverpinyin',
#   'fkxxyz',
#   'rime-cloverpinyin',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 650084)),
#  (925,
#   'ModelTC/LightX2V',
#   'ModelTC',
#   'LightX2V',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 662333)),
#  (926,
#   'qiwsir/ITArticles',
#   'qiwsir',
#   'ITArticles',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 674601)),
#  (927,
#   'eloialonso/diamond',
#   'eloialonso',
#   'diamond',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 686654)),
#  (928,
#   'skavngr/rapidscan',
#   'skavngr',
#   'rapidscan',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 698777)),
#  (929,
#   'john-kurkowski/tldextract',
#   'john-kurkowski',
#   'tldextract',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 711170)),
#  (930,
#   'Jon-Becker/prediction-market-analysis',
#   'Jon-Becker',
#   'prediction-market-analysis',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 723479)),
#  (931,
#   'iambus/xunlei-lixian',
#   'iambus',
#   'xunlei-lixian',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 734601)),
#  (932,
#   'kivy/buildozer',
#   'kivy',
#   'buildozer',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 746220)),
#  (933,
#   'amscanne/huptime',
#   'amscanne',
#   'huptime',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 758005)),
#  (934,
#   'facebookresearch/ConvNeXt-V2',
#   'facebookresearch',
#   'ConvNeXt-V2',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 769693)),
#  (935,
#   'lilianweng/stock-rnn',
#   'lilianweng',
#   'stock-rnn',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 783285)),
#  (936,
#   'moj-analytical-services/splink',
#   'moj-analytical-services',
#   'splink',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 799660)),
#  (937,
#   'powerfulseal/powerfulseal',
#   'powerfulseal',
#   'powerfulseal',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 813749)),
#  (938,
#   'ActiveState/code',
#   'ActiveState',
#   'code',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 827496)),
#  (939,
#   'dfunckt/django-rules',
#   'dfunckt',
#   'django-rules',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 839430)),
#  (940,
#   'adobe-research/custom-diffusion',
#   'adobe-research',
#   'custom-diffusion',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 852894)),
#  (941,
#   'DasyDong/developer-roadmap',
#   'DasyDong',
#   'developer-roadmap',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 866441)),
#  (942,
#   'python-control/python-control',
#   'python-control',
#   'python-control',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 879200)),
#  (943,
#   'gotcha/ipdb',
#   'gotcha',
#   'ipdb',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 892735)),
#  (944,
#   'apple/ml-hypersim',
#   'apple',
#   'ml-hypersim',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 905190)),
#  (945,
#   'ButTaiwan/iansui',
#   'ButTaiwan',
#   'iansui',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 919366)),
#  (946,
#   'apple/ml-cvnets',
#   'apple',
#   'ml-cvnets',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 933353)),
#  (947,
#   'qutip/qutip',
#   'qutip',
#   'qutip',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 946498)),
#  (948,
#   'ymcui/Chinese-LLaMA-Alpaca-3',
#   'ymcui',
#   'Chinese-LLaMA-Alpaca-3',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 960033)),
#  (949,
#   'vaguileradiaz/tinfoleak',
#   'vaguileradiaz',
#   'tinfoleak',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 973495)),
#  (950,
#   'etsy/logster',
#   'etsy',
#   'logster',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 35, 986782)),
#  (951,
#   'zhu-xlab/GlobalBuildingAtlas',
#   'zhu-xlab',
#   'GlobalBuildingAtlas',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 380)),
#  (952,
#   'anime-dl/anime-downloader',
#   'anime-dl',
#   'anime-downloader',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 13607)),
#  (953,
#   'alfiopuglisi/guietta',
#   'alfiopuglisi',
#   'guietta',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 27497)),
#  (954,
#   'CiaraStrawberry/TemporalKit',
#   'CiaraStrawberry',
#   'TemporalKit',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 41038)),
#  (955,
#   'nobody132/masr',
#   'nobody132',
#   'masr',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 54274)),
#  (956,
#   'ozmartian/vidcutter',
#   'ozmartian',
#   'vidcutter',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 67752)),
#  (957,
#   'eosphoros-ai/DB-GPT-Hub',
#   'eosphoros-ai',
#   'DB-GPT-Hub',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 81349)),
#  (958,
#   'RoboTwin-Platform/RoboTwin',
#   'RoboTwin-Platform',
#   'RoboTwin',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 94832)),
#  (959,
#   'SizheAn/PanoHead',
#   'SizheAn',
#   'PanoHead',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 108010)),
#  (960,
#   'davda54/sam',
#   'davda54',
#   'sam',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 121377)),
#  (961,
#   'alirezarezvani/claude-skills',
#   'alirezarezvani',
#   'claude-skills',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 134985)),
#  (962,
#   'openai/pixel-cnn',
#   'openai',
#   'pixel-cnn',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 148591)),
#  (963,
#   'nidhaloff/deep-translator',
#   'nidhaloff',
#   'deep-translator',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 162048)),
#  (964,
#   'noob-hackers/ipdrone',
#   'noob-hackers',
#   'ipdrone',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 175605)),
#  (965,
#   'aiortc/aioquic',
#   'aiortc',
#   'aioquic',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 188294)),
#  (966,
#   'bytewax/bytewax',
#   'bytewax',
#   'bytewax',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 201713)),
#  (967,
#   'jesolem/PCV',
#   'jesolem',
#   'PCV',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 215575)),
#  (968,
#   'sc0tfree/mentalist',
#   'sc0tfree',
#   'mentalist',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 229118)),
#  (969,
#   'owocki/pytrader',
#   'owocki',
#   'pytrader',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 242065)),
#  (970,
#   'Flolagale/mailin',
#   'Flolagale',
#   'mailin',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 254661)),
#  (971,
#   'hkchengrex/XMem',
#   'hkchengrex',
#   'XMem',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 266933)),
#  (972,
#   'WassimTenachi/PhySO',
#   'WassimTenachi',
#   'PhySO',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 278741)),
#  (973,
#   'philipperemy/tensorflow-1.4-billion-password-analysis',
#   'philipperemy',
#   'tensorflow-1.4-billion-password-analysis',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 291472)),
#  (974,
#   'nv-tlabs/3dgrut',
#   'nv-tlabs',
#   '3dgrut',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 303736)),
#  (975,
#   'stripe/stripe-python',
#   'stripe',
#   'stripe-python',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 316274)),
#  (976,
#   'guillaumegenthial/sequence_tagging',
#   'guillaumegenthial',
#   'sequence_tagging',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 328455)),
#  (977,
#   'pyupio/safety',
#   'pyupio',
#   'safety',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 341187)),
#  (978,
#   'WenjieDu/PyPOTS',
#   'WenjieDu',
#   'PyPOTS',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 353528)),
#  (979,
#   'facebookresearch/fairchem',
#   'facebookresearch',
#   'fairchem',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 364882)),
#  (980,
#   'Xyntax/POC-T',
#   'Xyntax',
#   'POC-T',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 377033)),
#  (981,
#   'horseee/Awesome-Efficient-LLM',
#   'horseee',
#   'Awesome-Efficient-LLM',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 389763)),
#  (982,
#   'yehengchen/Object-Detection-and-Tracking',
#   'yehengchen',
#   'Object-Detection-and-Tracking',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 401839)),
#  (983,
#   'weaveworks/grafanalib',
#   'weaveworks',
#   'grafanalib',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 415213)),
#  (984,
#   'brannondorsey/PassGAN',
#   'brannondorsey',
#   'PassGAN',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 428017)),
#  (985,
#   'TermuxHackz/X-osint',
#   'TermuxHackz',
#   'X-osint',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 440789)),
#  (986,
#   'xavierd/clang_complete',
#   'xavierd',
#   'clang_complete',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 453295)),
#  (987,
#   'julesontheroad/NSC_BUILDER',
#   'julesontheroad',
#   'NSC_BUILDER',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 465868)),
#  (988,
#   'yeti-platform/yeti',
#   'yeti-platform',
#   'yeti',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 477590)),
#  (989,
#   'psychopy/psychopy',
#   'psychopy',
#   'psychopy',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 489767)),
#  (990,
#   'petertodd/python-bitcoinlib',
#   'petertodd',
#   'python-bitcoinlib',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 502222)),
#  (991,
#   'pybuilder/pybuilder',
#   'pybuilder',
#   'pybuilder',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 514612)),
#  (992,
#   'arsaboo/homeassistant-config',
#   'arsaboo',
#   'homeassistant-config',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 527159)),
#  (993,
#   'pykeen/pykeen',
#   'pykeen',
#   'pykeen',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 542346)),
#  (994,
#   'gitless-vcs/gitless',
#   'gitless-vcs',
#   'gitless',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 555168)),
#  (995,
#   'hystax/optscale',
#   'hystax',
#   'optscale',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 567689)),
#  (996,
#   'vitali87/code-graph-rag',
#   'vitali87',
#   'code-graph-rag',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 580307)),
#  (997,
#   'ppwwyyxx/wechat-dump',
#   'ppwwyyxx',
#   'wechat-dump',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 592951)),
#  (998,
#   'Yuliang-Liu/Monkey',
#   'Yuliang-Liu',
#   'Monkey',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 604503)),
#  (999,
#   'youngfish42/Awesome-FL',
#   'youngfish42',
#   'Awesome-FL',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 616962)),
#  (1000,
#   'WuJie1010/Facial-Expression-Recognition.Pytorch',
#   'WuJie1010',
#   'Facial-Expression-Recognition.Pytorch',
#   'unknown',
#   True,
#   datetime.datetime(2026, 2, 25, 12, 1, 36, 629274)),
#  ...]
