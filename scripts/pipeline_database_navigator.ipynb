# %%
import duckdb
conn = duckdb.connect("../data/pipeline.duckdb")

# %%
conn.execute("SHOW TABLES").fetchall()
# Out:
# [('analyses',), ('projects',), ('versions',)]

# %%
projects_list = conn.execute("SELECT * FROM projects").fetchall()
count = 0
for project in projects_list:
    print(project)
    count += 1
    if count == 10:
        break
# Out:
# (1, 'pytorch/pytorch', 'pytorch', 'pytorch', 'unknown', True, datetime.datetime(2026, 2, 25, 12, 1, 25, 870871))
# (2, 'Shubhamsaboo/awesome-llm-apps', 'Shubhamsaboo', 'awesome-llm-apps', 'unknown', True, datetime.datetime(2026, 2, 25, 12, 1, 26, 406544))
# (3, 'fastapi/fastapi', 'fastapi', 'fastapi', 'unknown', True, datetime.datetime(2026, 2, 25, 12, 1, 26, 412608))
# (4, 'nvbn/thefuck', 'nvbn', 'thefuck', 'unknown', True, datetime.datetime(2026, 2, 25, 12, 1, 26, 418314))
# (5, 'openai/whisper', 'openai', 'whisper', 'unknown', True, datetime.datetime(2026, 2, 25, 12, 1, 26, 424086))
# (6, 'microsoft/markitdown', 'microsoft', 'markitdown', 'unknown', True, datetime.datetime(2026, 2, 25, 12, 1, 26, 431647))
# (7, 'django/django', 'django', 'django', 'unknown', True, datetime.datetime(2026, 2, 25, 12, 1, 26, 437780))
# (8, 'home-assistant/core', 'home-assistant', 'core', 'unknown', True, datetime.datetime(2026, 2, 25, 12, 1, 26, 444531))
# (9, '3b1b/manim', '3b1b', 'manim', 'unknown', True, datetime.datetime(2026, 2, 25, 12, 1, 26, 450581))
# (10, 'bregman-arie/devops-exercises', 'bregman-arie', 'devops-exercises', 'unknown', True, datetime.datetime(2026, 2, 25, 12, 1, 26, 456938))

# %%
results = conn.execute("""
    SELECT language, COUNT(*) AS count
    FROM projects
    GROUP BY language
    ORDER BY count DESC
""").fetchall()

print(f"{'Language':<20} {'Count':>6}")
print("-" * 28)
for language, count in results:
    print(f"{language:<20} {count:>6}")

print(f"\nTotal projects: {sum(r[1] for r in results)}")
# Out:
# Language              Count
# ----------------------------
# unknown                3106
#
# Total projects: 3106
